# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # 强制只用 CPU
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"   # 可选：减少日志噪音

from DECIMER import predict_SMILES

smiles = predict_SMILES("mol_png/Ph基团2.png")
print(f"识别结果: {smiles}")
# Out:
# 识别结果: C1=CC=C(C=C1)[Pb]
